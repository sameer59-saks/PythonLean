# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''
import random
#take user input

#take computer input

#compare user and computer input

#choose the winner

user_input = input('Enter Your Choice Rock Paper Scissoor: ')

choices = ['rock', 'paper', 'scissors']

computer_input = random.choice(choices)


if user_input == 'rock':
  if computer_input == 'scissors':
    print(computer_input)
    print('user wins')
    print(rock)
    print('computer input')
    print(scissors)
  elif computer_input == 'paper':
    print(computer_input)
    print('computer wins')
    print(paper)
  elif computer_input == 'rock':
    print(computer_input)
    print('It is a draw')

if user_input == 'scissors':
  if computer_input == 'paper':
    print(computer_input)
    print('user wins')
    print(scissors)
    print()
    print(paper)
  elif computer_input == 'rock':
    print(computer_input)
    print('computer wins')
    print(rock)
  elif computer_input == 'scissors':
    print(computer_input)
    print('It is a draw')

if user_input == 'paper':
  if computer_input == 'rocks':
    print(computer_input)
    print('user wins')
    print(rock)
  elif computer_input == 'scissors':
    print(computer_input)
    print('computer wins')
    print(scissors)
  elif computer_input == 'paper':
    print('It is a draw')
